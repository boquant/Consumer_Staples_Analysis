# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

working_directory = '/content/drive/MyDrive/Projects/5261/Data/S&P500_data/'  # <-- adjust your own document path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv(working_directory + 'tech_indicator_for_stock_1997_2024.csv')

df1.sample(10)
# Out:
#              Date                          Company Ticker            Sector  \
# 441    2008-02-01  Goldman Sachs Group, Inc. (The)     GS         Financial
# 6146   2007-11-01   Procter & Gamble Company (The)     PG  Consumer Staples
# 10565  2012-02-01               Exelon Corporation    EXC         Utilities
# 8238   2014-03-01                        AT&T Inc.      T     Communication
# 9723   1997-12-01  Duke Energy Corporation (Holdin    DUK         Utilities
# 8154   2007-03-01                        AT&T Inc.      T     Communication
# 140    2008-09-01            JP Morgan Chase & Co.    JPM         Financial
# 9309   2019-06-01          DuPont de Nemours, Inc.     DD         Materials
# 6211   2013-04-01   Procter & Gamble Company (The)     PG  Consumer Staples
# 222    2015-07-01            JP Morgan Chase & Co.    JPM         Financial
#
#              RSI         PE       ROC
# 441    44.504931  12.283825       NaN
# 6146   78.101893  26.390125  0.057112
# ...

# %%
df1
# Out:
#              Date                Company Ticker     Sector        RSI  \
# 0      1997-01-01  JP Morgan Chase & Co.    JPM  Financial        NaN
# 1      1997-02-01  JP Morgan Chase & Co.    JPM  Financial        NaN
# 2      1997-03-01  JP Morgan Chase & Co.    JPM  Financial        NaN
# 3      1997-04-01  JP Morgan Chase & Co.    JPM  Financial        NaN
# 4      1997-05-01  JP Morgan Chase & Co.    JPM  Financial        NaN
# ...           ...                    ...    ...        ...        ...
# 10715  2024-08-01     Exelon Corporation    EXC  Utilities  47.061032
# 10716  2024-09-01     Exelon Corporation    EXC  Utilities  51.713916
# 10717  2024-10-01     Exelon Corporation    EXC  Utilities  52.773795
# 10718  2024-11-01     Exelon Corporation    EXC  Utilities  58.943162
# 10719  2024-12-01     Exelon Corporation    EXC  Utilities  51.639172
#
#               PE       ROC
# 0      11.819431       NaN
# 1      11.819431       NaN
# 2      11.819431       NaN
# ...

# %%
num_companies = df1['Sector'].nunique()
num_companies
# Out:
# 11

# %%
df2 = pd.read_csv(working_directory + 'adjusted_monthly_close_prices_by_company_1997_2024.csv')

df2.sample(10)
# Out:
#             JPM          GS        BAC         XOM         CVX        SLB  \
# 335  238.401717  580.305460  44.969921  109.223527  149.308916  39.503969
# 100   20.931772   74.293571  29.502948   28.721882   24.787991  22.453337
# 172   29.843594  111.062637   9.455080   48.082309   59.124806  59.583074
# 144   17.138078   59.612328   7.360727   43.046807   37.957470  29.052067
# 258   90.560653  197.073100  25.169117   59.963342   92.664620  55.329661
# 160   27.229759  109.828028  12.961623   35.913298   42.579425  44.515557
# 233   49.162606  124.903333  11.276151   61.082650   70.489700  60.761743
# 279   80.056346  153.979137  19.888728   33.363154   67.153199  14.067238
# 185   24.063190   73.897619   6.076322   48.927137   59.926239  46.030352
# 297  152.844514  364.802952  41.677684   55.075524   95.373113  30.568544
#
#              GE         CAT         MMM         JNJ  ...        EQR  \
# 335  169.930028  376.900378  129.407661  145.978497  ...  71.249786
# ...

# %%
df3 = pd.read_csv(working_directory + 'adjusted_close_prices_by_company_1997_2024.csv')

df3.sample(10)
# Out:
#             Date         JPM          GS        BAC         XOM         CVX  \
# 2280  2006-01-25   23.265015   98.945999  29.551430   31.343557   29.416254
# 3045  2009-02-09   18.250284   74.106117   5.407049   43.947418   39.097248
# 7043  2024-12-27  238.462036  573.337036  44.061939  105.536011  142.420319
# 1155  2001-08-01   21.821028   60.745522  17.523380   19.443102   18.743647
# 3996  2012-11-16   28.087397   91.776924   7.275641   52.460114   61.779774
# 3471  2010-10-18   25.797865  118.653496   9.751233   38.077393   47.393246
# 2504  2006-12-13   29.460804  147.859467  36.676617   41.054974   36.878849
# 4412  2014-07-16   43.742687  138.353455  12.438432   65.589745   82.993896
# 1777  2004-01-27   22.515591   73.447235  25.034716   20.520248   19.762375
# 5161  2017-07-06   75.312073  191.640930  20.625084   56.027668   74.613770
#
#             SLB          GE         CAT         MMM  ...         PSA  \
# ...
